# %%
import papermill as pm

pm.execute_notebook(
   './test.ipynb',
   './test.ipynb',
   parameters = dict(para=0.6)
)
# Out:
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# ---------------------------------------------------------------------------
# NoSuchKernel                              Traceback (most recent call last)
# Cell In[1], line 3
#       1 import papermill as pm
# ----> 3 pm.execute_notebook(
#       4    './test.ipynb',
#       5    './test.ipynb',
#       6    parameters = dict(para=0.6)
#       7 )
#
# File D:\Users\xiaowu\anaconda3\envs\bci\Lib\site-packages\papermill\execute.py:116, in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     114 # Execute the Notebook in `cwd` if it is set
#     115 with chdir(cwd):
# --> 116     nb = papermill_engines.execute_notebook_with_engine(
#     117         engine_name,
#     118         nb,
#     119         input_path=input_path,
# ...
