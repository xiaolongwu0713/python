# %% [markdown]
# ###
#
# 200223_FGY/200215_HYJ/200216_ZYJ: trigger name is not the same as paradigm: stimus/s 1/2/3/4/5/6/7/8
#
#
# 200425_WHJ/200509_LWC/200511_SLF: same as the paradigm;

# %%
import mne

# %%
filename='D:/data/ruijin/RuiJinData20201108/ruijin/200511_SLF/slf0511.vhdr'
raw=mne.io.read_raw_brainvision(filename)

# %%
# %matplotlib qt
raw.plot()
# Out:
# <MNEBrowseFigure size 3072x1779 with 4 Axes>
